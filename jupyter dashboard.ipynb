# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Charger les données
file_path = "rapport_pharmacie.xlsx"
stats_df = pd.read_excel(file_path, sheet_name="Statistiques descriptives", engine="openpyxl")
monthly_df = pd.read_excel(file_path, sheet_name="Synthèse mensuelle", engine="openpyxl")

# %%
# Ajouter une colonne avec les noms de mois en français
mois_fr = ['janvier', 'février', 'mars', 'avril', 'mai', 'juin',
           'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']
monthly_df["NomMois"] = monthly_df["Month"].apply(lambda x: mois_fr[x - 1])
monthly_df["Date"] = pd.to_datetime(monthly_df[["Year", "Month"]].assign(DAY=1))

# %%
# Colonnes numériques
numeric_cols = monthly_df.select_dtypes(include='number').columns[2:]
monthly_df["TotalVentes"] = monthly_df[numeric_cols].sum(axis=1)
total_sales = monthly_df[numeric_cols].sum()

# %%
# Titre principal
st.title("📊 Dashboard des ventes de médicaments - Pharmacie")
# Out:
# 2025-10-10 15:48:33.232 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.405
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/dashboard/venv/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-10-10 15:48:33.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Onglets
tab1, tab2, tab3 = st.tabs(["📊 Statistiques & Synthèse", "📈 Évolution & Recherche", "🧑‍⚕️ Analyse stratégique"])
# Out:
# 2025-10-10 15:48:33.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Onglet 1 : Statistiques descriptives + Synthèse
with tab1:
    st.header("🔍 Statistiques descriptives")
    st.dataframe(stats_df, use_container_width=True)

    st.header("📊 Synthèse des ventes totales")
    fig2, ax2 = plt.subplots()
    sns.barplot(x=total_sales.index, y=total_sales.values, ax=ax2)
    ax2.set_title("Ventes totales par type de médicament")
    ax2.set_xlabel("Type de médicament")
    ax2.set_ylabel("Ventes totales")
    plt.xticks(rotation=45)
    st.pyplot(fig2, use_container_width=True)
# Out:
# 2025-10-10 15:48:33.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.458 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:33.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.592 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:33.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Onglet 2 : Évolution mensuelle + Recherche ciblée
with tab2:
    st.header("📈 Évolution mensuelle des ventes")
    selected_product = st.selectbox("Choisissez un médicament", monthly_df.columns[2:])
    fig, ax = plt.subplots()
    sns.lineplot(data=monthly_df, x="Date", y=selected_product, ax=ax)
    ax.set_title(f"Évolution des ventes - {selected_product}")
    ax.set_xlabel("Date")
    ax.set_ylabel("Ventes")
    st.pyplot(fig, use_container_width=True)

    st.header("🔎 Recherche ciblée")
    selected_year = st.selectbox("Année", sorted(monthly_df["Year"].unique()))
    selected_month_name = st.selectbox("Mois", mois_fr)
    selected_month = mois_fr.index(selected_month_name) + 1
    selected_product_2 = st.selectbox("Produit", monthly_df.columns[2:])
    filtered_value = monthly_df[
        (monthly_df["Year"] == selected_year) &
        (monthly_df["Month"] == selected_month)
    ][selected_product_2].values
    if filtered_value.size > 0:
        st.success(f"Ventes de {selected_product_2} en {selected_month_name} {selected_year} : {filtered_value[0]}")
    else:
        st.warning("Aucune donnée disponible pour cette sélection.")
# Out:
# 2025-10-10 15:48:33.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.806 Session state does not function when running a script without `streamlit run`
# 2025-10-10 15:48:33.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:33.870 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:33.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Onglet 3 : Analyse stratégique
with tab3:
    st.header("📊 Vue d’ensemble des ventes")
    fig_overview, ax_overview = plt.subplots()
    sns.lineplot(data=monthly_df, x="Date", y="TotalVentes", ax=ax_overview)
    ax_overview.set_title("Vue d’ensemble des ventes mensuelles")
    st.pyplot(fig_overview, use_container_width=True)

    st.header("📉 Produits à forte variation")
    variations = monthly_df[numeric_cols].std().sort_values(ascending=False)
    fig_var, ax_var = plt.subplots()
    sns.barplot(x=variations.index, y=variations.values, ax=ax_var)
    ax_var.set_title("Produits à forte variation de ventes")
    ax_var.set_ylabel("Écart-type des ventes")
    plt.xticks(rotation=45)
    st.pyplot(fig_var, use_container_width=True)

    st.header("🏆 Produits les plus vendus")
    top_products = total_sales.sort_values(ascending=False).head(5)
    fig_top, ax_top = plt.subplots()
    sns.barplot(x=top_products.index, y=top_products.values, ax=ax_top)
    ax_top.set_title("Top 5 des produits les plus vendus")
    st.pyplot(fig_top, use_container_width=True)

    st.header("📅 Saisonnalité des ventes")
    monthly_avg = monthly_df.groupby("Month")[numeric_cols].mean()
    fig_season, ax_season = plt.subplots()
    sns.heatmap(monthly_avg.T, cmap="YlGnBu", ax=ax_season)
    ax_season.set_title("Saisonnalité des ventes par produit")
    st.pyplot(fig_season, use_container_width=True)

    st.header("📉 Produits faibles en ventes")
    low_products = total_sales.sort_values().head(5)
    fig_low, ax_low = plt.subplots()
    sns.barplot(x=low_products.index, y=low_products.values, ax=ax_low)
    ax_low.set_title("Produits avec les ventes les plus faibles")
    st.pyplot(fig_low, use_container_width=True)

    st.header("📊 Comparaison par catégorie")
    fig_cat, ax_cat = plt.subplots()
    sns.boxplot(data=monthly_df[numeric_cols], ax=ax_cat)
    ax_cat.set_title("Distribution des ventes par catégorie de médicament")
    plt.xticks(rotation=45)
    st.pyplot(fig_cat, use_container_width=True)

    st.header("📈 Analyse temporelle")
    fig_time, ax_time = plt.subplots()
    sns.lineplot(data=monthly_df, x="Date", y="TotalVentes", ax=ax_time)
    ax_time.set_title("Analyse temporelle des ventes globales")
    st.pyplot(fig_time, use_container_width=True)

    st.header("💡 Opportunités d’amélioration")
    st.markdown("""
    - Renforcer la promotion des produits à faible vente.
    - Adapter les stocks selon la saisonnalité observée.
    - Cibler les produits à forte variation pour des campagnes spécifiques.
    """)

    st.header("📌 Propositions stratégiques")
    st.markdown("""
    - Mettre en place un suivi mensuel automatisé des ventes.
    - Développer des partenariats pour les produits clés.
    - Optimiser les catégories sous-performantes.
    """)
# Out:
# 2025-10-10 15:48:34.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.177 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:34.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.430 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:34.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.642 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:34.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:34.922 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:34.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.224 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:35.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.590 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:35.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:35.948 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2025-10-10 15:48:35.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-10 15:48:36.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
